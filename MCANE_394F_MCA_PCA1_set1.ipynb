# %% [markdown]
# <a href="https://colab.research.google.com/github/ManpreetRoy/MCANE-394E394F_PCA1/blob/main/MCANE_394F_MCA_PCA1_set1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Data Science Lab - SET 1
# # MCAN-E394F

# %% [markdown]
# Q1. NumPy Matrix Operations
# Write a Python program using NumPy to create the following two matrices:
#
# Matrix A
# [2 4 6
#  1 3 5
#  7 8 9]
#
# Matrix B
# [1 2 3
#  4 5 6
#  7 8 9]
#
# Perform:
# 1. Matrix addition
# 2. Matrix subtraction
# 3. Element-wise multiplication
# 4. Matrix multiplication
# 5. Transpose of Matrix A

# %% [markdown]
# Q2. NumPy Statistical Operations
# Create the following NumPy matrix:
# [12 25 18
#  30 15 22
#  10 28 35]
#
# Write a program to find:
# 1. Sum of each row
# 2. Sum of each column
# 3. Mean of all elements
# 4. Maximum element
# 5. Minimum element
# 6. Trace of the matrix

# %% [markdown]
# Q3. Student Dictionary
# Create a dictionary containing the name, age, department, and marks of a student
# Write a program to:
# 1. Display the complete dictionary.
# 2. Display the student's name and marks.
# 3. Add "city": "Kolkata".
# 4. Change the marks to a new value.
# 5. Display the updated dictionary.

# %% [markdown]
# Q4. Sales Dictionary
# Create a dictionary containing the following sales data:
#
# | Day | Sales |
# |-----------|-------|
# | Monday | 2500 |
# | Tuesday | 3200 |
# | Wednesday | 2800 |
# | Thursday | 3500 |
# | Friday | 4100 |
#
# Find:
# 1. Total sales
# 2. Average sales
# 3. Day with the highest sales
# 4. Day with the lowest sales

# %% [markdown]
# Q5. NumPy Element-wise Comparison
# Create the following two NumPy arrays:
# A = [4, 8, 3, 12, 7, 15, 2, 10]
# B = [5, 6, 3, 9, 8, 14, 4, 10]
#
# Write a Python program to:
# 1. Display both arrays.
# 2. Compare the two arrays element-wise.
# 3. Display the elements of A that are greater than the corresponding elements of B.
# 4. Count how many elements of A are greater than B.
# 5. Find the positions where both arrays contain equal elements.
