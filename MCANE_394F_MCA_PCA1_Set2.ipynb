# %% [markdown]
# <a href="https://colab.research.google.com/github/ManpreetRoy/MCANE-394E394F_PCA1/blob/main/MCANE_394F_MCA_PCA1_Set2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Data Science Lab - SET 2
# # MCAN-E394F

# %% [markdown]
# Q1. NumPy Matrix Properties
# Create the following 4x4 NumPy matrix:
#
# [ 5  8  12 15
#   7  3  10 18
#  20  6   9 14
#  11 16   4 25 ]
#
# Perform:
# 1. Display the first two rows.
# 2. Display the last two columns.
# 3. Extract the diagonal elements.
# 4. Extract the middle 2x2 sub-matrix.
# 5. Reverse the rows.

# %% [markdown]
# Q2. NumPy Conditional Operations
# Create a NumPy array:
# [4, 9, 12, 7, 15, 2, 18, 11, 6, 20]
#
# Write a program to:
# 1. Find elements greater than 10.
# 2. Replace all elements greater than 10 with 0.
# 3. Count even elements.
# 4. Count odd elements.
# 5. Find the positions of elements greater than 10.

# %% [markdown]
# Q3. Student Marks Dictionary
# Create the following dictionary:
# marks = {
#   "Amit": 78,
#   "Riya": 92,
#   "Rahul": 65,
#   "Sneha": 88,
#   "Arjun": 74,
#   "Priya": 95
# }
# Write a program to:
# 1. Calculate the average marks.
# 2. Find the student with the highest marks.
# 3. Find the student with the lowest marks.
# 4. Display students scoring 80 or above.

# %% [markdown]
# Q4. Dictionary -
# Create two lists:
# Names = ["Amit", "Riya", "Rahul", "Sneha", "Arjun"]
# Marks = [75, 88, 67, 92, 81]
#
# 1. Create a dictionary.
# 2. Display the dictionary.
# 3. Calculate the average marks.
# 4. Find the highest marks.
# 5. Display the name of the highest-scoring student.

# %% [markdown]
# Q5. Dictionary Missing Value Counter
# Consider the following dataset dictionary:
# data = {
#   "Name": ["Amit", "Riya", "Rahul", "Sneha", "Arjun"],
#   "Age": [20, 21, "Missing", 22, 20],
#   "Marks": [78, "Missing", 67, 91, "Missing"],
#   "City": ["Kolkata", "Delhi", "Missing", "Mumbai", "Kolkata"]
# }
#
# Write a Python program using a dictionary to:
# 1. Display the complete dataset dictionary.
# 2. Count the number of "Missing" values in each column.
# 3. Display the column having the maximum number of missing values.
# 4. Calculate the total number of missing values in the dataset.
# 5. Display the result in a suitable format.
